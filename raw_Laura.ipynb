# %% [markdown]
# <a href="https://colab.research.google.com/github/lauramendescd/sinasc-analise/blob/main/raw_Laura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Bibliotecas necessárias
import os
from google.colab import drive
from google.cloud import bigquery
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Definindo o caminho para o arquivo de credenciais no Google Colab
path_to_credentials = '/content/projeto-iii-425700-4b6d9ee58aae.json'

# Definindo a variável de ambiente para as credenciais do Google Cloud
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = path_to_credentials

# Inicializando o cliente do BigQuery
client = bigquery.Client()

# Consulta SQL para selecionar todas as colunas dos dados do SINASC do estado do Ceará a partir de 2014
query = """
SELECT *
FROM `basedosdados.br_ms_sinasc.microdados`
WHERE EXTRACT(YEAR FROM data_nascimento) >= 2014
AND sigla_uf = 'CE'
"""

# Executar a consulta
query_job = client.query(query)

# Obtendo os resultados em um DataFrame do Pandas
df = query_job.to_dataframe()
df
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# <ipython-input-7-426a45c3cf32> in <cell line: 0>()
#       6
#       7 # Inicializando o cliente do BigQuery
# ----> 8 client = bigquery.Client()
#       9
#      10 # Consulta SQL para selecionar todas as colunas dos dados do SINASC do estado do Ceará a partir de 2014
#
# /usr/local/lib/python3.11/dist-packages/google/cloud/bigquery/client.py in __init__(self, project, credentials, _http, location, default_query_job_config, default_load_job_config, client_info, client_options, default_job_creation_mode)
#     256         # assert isinstance(client_options, google.api_core.client_options.ClientOptions)
#     257
# --> 258         super(Client, self).__init__(
#     259             project=project,
#     260             credentials=credentials,
#
# /usr/local/lib/python3.11/dist-packages/google/cloud/client/__init__.py in __init__(self, project, credentials, client_options, _http)
#     336
#     337     def __init__(self, project=None, credentials=None, client_options=None, _http=None):
# --> 338         _ClientProjectMixin.__init__(self, project=project, credentials=credentials)
#     339         Client.__init__(
#     340             self, credentials=credentials, client_options=client_options, _http=_http
#
# /usr/local/lib/python3.11/dist-packages/google/cloud/client/__init__.py in __init__(self, project, credentials)
#     284
#     285         if project is None:
# --> 286             project = self._determine_default(project)
#     287
#     288         if project is None:
#
# /usr/local/lib/python3.11/dist-packages/google/cloud/client/__init__.py in _determine_default(project)
#     303     def _determine_default(project):
#     304         """Helper:  use default project detection."""
# --> 305         return _determine_default_project(project)
#     306
#     307
#
# /usr/local/lib/python3.11/dist-packages/google/cloud/_helpers/__init__.py in _determine_default_project(project)
#     150     """
#     151     if project is None:
# --> 152         _, project = google.auth.default()
#     153     return project
#     154
#
# /usr/local/lib/python3.11/dist-packages/google/auth/_default.py in default(scopes, request, quota_project_id, default_scopes)
#     683
#     684     for checker in checkers:
# --> 685         credentials, project_id = checker()
#     686         if credentials is not None:
#     687             credentials = with_scopes_if_required(
#
# /usr/local/lib/python3.11/dist-packages/google/auth/_default.py in <lambda>()
#     676         # safely set on the returned credentials since requires_scopes will
#     677         # guard against setting scopes on user credentials.
# --> 678         lambda: _get_explicit_environ_credentials(quota_project_id=quota_project_id),
#     679         lambda: _get_gcloud_sdk_credentials(quota_project_id=quota_project_id),
#     680         _get_gae_credentials,
#
# /usr/local/lib/python3.11/dist-packages/google/auth/_default.py in _get_explicit_environ_credentials(quota_project_id)
#     291
#     292     if explicit_file is not None:
# --> 293         credentials, project_id = load_credentials_from_file(
#     294             os.environ[environment_vars.CREDENTIALS], quota_project_id=quota_project_id
#     295         )
#
# /usr/local/lib/python3.11/dist-packages/google/auth/_default.py in load_credentials_from_file(filename, scopes, default_scopes, quota_project_id, request)
#     123     """
#     124     if not os.path.exists(filename):
# --> 125         raise exceptions.DefaultCredentialsError(
#     126             "File {} was not found.".format(filename)
#     127         )
#
# DefaultCredentialsError: File /content/projeto-iii-425700-4b6d9ee58aae.json was not found.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1171699 entries, 0 to 1171698
# Data columns (total 66 columns):
#  #   Column                             Non-Null Count    Dtype
# ---  ------                             --------------    -----
#  0   ano                                1171699 non-null  Int64
#  1   sigla_uf                           1171699 non-null  object
#  2   sequencial_nascimento              1171699 non-null  object
#  3   id_municipio_nascimento            1171699 non-null  object
#  4   local_nascimento                   1171699 non-null  object
#  5   codigo_estabelecimento             1166496 non-null  object
#  6   data_nascimento                    1171699 non-null  dbdate
#  7   hora_nascimento                    1057445 non-null  dbtime
#  8   sexo                               1171699 non-null  object
#  9   peso                               1171659 non-null  Int64
#  10  raca_cor                           978145 non-null   object
#  11  apgar1                             1154696 non-null  Int64
#  12  apgar5                             1154687 non-null  Int64
#  13  id_anomalia                        1112605 non-null  object
#  14  codigo_anomalia                    10965 non-null    object
#  15  semana_gestacao                    1123930 non-null  Int64
#  16  semana_gestacao_estimada           1110483 non-null  object
#  17  gestacao_agr                       1126084 non-null  object
#  18  tipo_gravidez                      1162038 non-null  object
#  19  tipo_parto                         1169816 non-null  object
#  20  inicio_pre_natal                   1084630 non-null  object
#  21  pre_natal                          1124659 non-null  Int64
#  22  pre_natal_agr                      1171048 non-null  object
#  23  classificacao_pre_natal            1171699 non-null  object
#  24  quantidade_filhos_vivos            1044120 non-null  Int64
#  25  quantidade_filhos_mortos           983804 non-null   Int64
#  26  id_pais_mae                        1134612 non-null  object
#  27  id_uf_mae                          1134611 non-null  object
#  28  id_municipio_mae                   1130066 non-null  object
#  29  id_pais_residencia                 782701 non-null   object
#  30  id_municipio_residencia            1171699 non-null  object
#  31  data_nascimento_mae                1018718 non-null  dbdate
#  32  idade_mae                          1171699 non-null  Int64
#  33  escolaridade_mae                   1127157 non-null  object
#  34  serie_escolar_mae                  600250 non-null   object
#  35  escolaridade_2010_mae              1104027 non-null  object
#  36  escolaridade_2010_agr_mae          1104027 non-null  object
#  37  estado_civil_mae                   1147201 non-null  object
#  38  ocupacao_mae                       917381 non-null   object
#  39  raca_cor_mae                       959901 non-null   object
#  40  gestacoes_ant                      1041263 non-null  Int64
#  41  quantidade_parto_normal            985210 non-null   Int64
#  42  quantidade_parto_cesareo           980762 non-null   Int64
#  43  data_ultima_menstruacao            753302 non-null   dbdate
#  44  tipo_apresentacao                  1117366 non-null  object
#  45  inducao_parto                      1098947 non-null  object
#  46  cesarea_antes_parto                992037 non-null   object
#  47  tipo_robson                        1171699 non-null  object
#  48  idade_pai                          168627 non-null   Int64
#  49  cartorio                           0 non-null        object
#  50  registro_cartorio                  0 non-null        object
#  51  data_registro_cartorio             0 non-null        dbdate
#  52  origem                             1171699 non-null  object
#  53  numero_lote                        1171692 non-null  Int64
#  54  versao_sistema                     1171692 non-null  object
#  55  data_cadastro                      1171698 non-null  dbdate
#  56  data_recebimento                   1170644 non-null  dbdate
#  57  data_recebimento_original          279864 non-null   dbdate
#  58  diferenca_data                     1171677 non-null  Int64
#  59  data_declaracao                    1117317 non-null  dbdate
#  60  funcao_responsavel                 1095839 non-null  object
#  61  documento_responsavel              1148451 non-null  object
#  62  formacao_profissional_responsavel  1143427 non-null  object
#  63  status_dn                          1171692 non-null  object
#  64  status_dn_nova                     1171699 non-null  object
#  65  paridade                           1171699 non-null  object
# dtypes: Int64(15), dbdate(8), dbtime(1), object(42)
# memory usage: 606.8+ MB

# %%
df.head()
# Out:
#     ano sigla_uf sequencial_nascimento id_municipio_nascimento  \
# 0  2020       CE                263194                 2305209
# 1  2020       CE               1678088                 2306405
# 2  2020       CE               1649286                 2303709
# 3  2020       CE                274051                 2307650
# 4  2020       CE                270808                 2307304
#
#   local_nascimento codigo_estabelecimento data_nascimento hora_nascimento  \
# 0                3                   None      2020-02-22        01:40:00
# 1                4                   None      2020-07-15        02:00:00
# 2                4                   None      2020-10-30        09:17:00
# 3                3                   None      2020-03-31        13:20:00
# 4                1                0133094      2020-05-29        09:50:00
#
#   sexo  peso  ... data_recebimento  data_recebimento_original  diferenca_data  \
# 0    1  2550  ...       2020-03-12                        NaT              19
# 1    2  2564  ...       2021-02-03                        NaT             203
# 2    1  3455  ...       2020-11-17                        NaT              18
# 3    2  3286  ...       2020-04-08                        NaT               8
# 4    2  2980  ...       2020-08-03                        NaT              66
#
#   data_declaracao funcao_responsavel  documento_responsavel  \
# 0      2020-02-22                  2                      3
# 1      2020-07-15               None                      0
# 2      2020-10-30                  2                      3
# 3      2020-03-31                  2                      3
# 4      2020-05-29                  2                      3
#
#   formacao_profissional_responsavel status_dn status_dn_nova paridade
# 0                                 3         0              1        0
# 1                                 9         0              1        0
# 2                                 1         0              1        0
# 3                                 9         0              1        0
# 4                                 1         0              1        0
#
# [5 rows x 66 columns]

# %%
df.describe()
# Out:
#                ano         peso     apgar1     apgar5  semana_gestacao  \
# count    1171699.0    1171659.0  1154696.0  1154687.0        1123930.0
# mean   2018.082613  3209.958111   8.186777   9.049209        38.487868
# std       2.678033   571.682627   1.701112   1.441736         2.421943
# min         2014.0        100.0        0.0        0.0             19.0
# 25%         2016.0       2929.5        8.0        9.0             38.0
# 50%         2018.0       3250.0        8.0        9.0             39.0
# 75%         2020.0       3560.0        9.0        9.0             40.0
# max         2023.0       7000.0       99.0       99.0             45.0
#
#        pre_natal  quantidade_filhos_vivos  quantidade_filhos_mortos  \
# count  1124659.0                1044120.0                  983804.0
# mean    8.336492                 1.071859                  0.270337
# std     5.844783                 1.269897                   0.63177
# min          0.0                      0.0                       0.0
# 25%          6.0                      0.0                       0.0
# 50%          8.0                      1.0                       0.0
# 75%         10.0                      2.0                       0.0
# max         99.0                     99.0                      99.0
#
#        idade_mae  gestacoes_ant  quantidade_parto_normal  \
# count  1171699.0      1041263.0                 985210.0
# mean   26.565771       1.303736                 0.771576
# std     6.710615       1.479534                 1.309589
# min          8.0            0.0                      0.0
# 25%         21.0            0.0                      0.0
# 50%         26.0            1.0                      0.0
# 75%         31.0            2.0                      1.0
# max         99.0           99.0                     99.0
#
#        quantidade_parto_cesareo  idade_pai      numero_lote  diferenca_data
# count                  980762.0   168627.0        1171692.0       1171677.0
# mean                   0.371585  31.113493  20182098.809479       60.545421
# std                    0.696525   8.163317     26994.763961      108.619176
# min                         0.0        9.0       20140001.0             0.0
# 25%                         0.0       25.0       20160012.0            15.0
# 50%                         0.0       30.0       20180021.0            26.0
# 75%                         1.0       36.0       20200057.0            46.0
# max                        99.0       99.0       20230028.0           816.0

# %%
# Verificar as primeiras linhas do DataFrame
print(df.head())

# Verificar informações gerais sobre o DataFrame
print(df.info())

# Verificar estatísticas descritivas para variáveis numéricas
print(df.describe())

# Verificar valores únicos de variáveis categóricas
for col in df.select_dtypes(include=['object']).columns:
    print(f"\nValores únicos em {col}:")
    print(df[col].unique())

# Verificar se há valores faltantes
print(df.isnull().sum())
# Out:
#     ano sigla_uf sequencial_nascimento id_municipio_nascimento  \
# 0  2020       CE                263194                 2305209
# 1  2020       CE               1678088                 2306405
# 2  2020       CE               1649286                 2303709
# 3  2020       CE                274051                 2307650
# 4  2020       CE                270808                 2307304
#
#   local_nascimento codigo_estabelecimento data_nascimento hora_nascimento  \
# 0                3                   None      2020-02-22        01:40:00
# 1                4                   None      2020-07-15        02:00:00
# 2                4                   None      2020-10-30        09:17:00
# 3                3                   None      2020-03-31        13:20:00
# 4                1                0133094      2020-05-29        09:50:00
#
#   sexo  peso  ... data_recebimento  data_recebimento_original  diferenca_data  \
# 0    1  2550  ...       2020-03-12                        NaT              19
# 1    2  2564  ...       2021-02-03                        NaT             203
# 2    1  3455  ...       2020-11-17                        NaT              18
# 3    2  3286  ...       2020-04-08                        NaT               8
# 4    2  2980  ...       2020-08-03                        NaT              66
#
#   data_declaracao funcao_responsavel  documento_responsavel  \
# 0      2020-02-22                  2                      3
# 1      2020-07-15               None                      0
# 2      2020-10-30                  2                      3
# 3      2020-03-31                  2                      3
# 4      2020-05-29                  2                      3
#
#   formacao_profissional_responsavel status_dn status_dn_nova paridade
# 0                                 3         0              1        0
# 1                                 9         0              1        0
# 2                                 1         0              1        0
# 3                                 9         0              1        0
# 4                                 1         0              1        0
#
# [5 rows x 66 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1171699 entries, 0 to 1171698
# Data columns (total 66 columns):
#  #   Column                             Non-Null Count    Dtype
# ---  ------                             --------------    -----
#  0   ano                                1171699 non-null  Int64
#  1   sigla_uf                           1171699 non-null  object
#  2   sequencial_nascimento              1171699 non-null  object
#  3   id_municipio_nascimento            1171699 non-null  object
#  4   local_nascimento                   1171699 non-null  object
#  5   codigo_estabelecimento             1166496 non-null  object
#  6   data_nascimento                    1171699 non-null  dbdate
#  7   hora_nascimento                    1057445 non-null  dbtime
#  8   sexo                               1171699 non-null  object
#  9   peso                               1171659 non-null  Int64
#  10  raca_cor                           978145 non-null   object
#  11  apgar1                             1154696 non-null  Int64
#  12  apgar5                             1154687 non-null  Int64
#  13  id_anomalia                        1112605 non-null  object
#  14  codigo_anomalia                    10965 non-null    object
#  15  semana_gestacao                    1123930 non-null  Int64
#  16  semana_gestacao_estimada           1110483 non-null  object
#  17  gestacao_agr                       1126084 non-null  object
#  18  tipo_gravidez                      1162038 non-null  object
#  19  tipo_parto                         1169816 non-null  object
#  20  inicio_pre_natal                   1084630 non-null  object
#  21  pre_natal                          1124659 non-null  Int64
#  22  pre_natal_agr                      1171048 non-null  object
#  23  classificacao_pre_natal            1171699 non-null  object
#  24  quantidade_filhos_vivos            1044120 non-null  Int64
#  25  quantidade_filhos_mortos           983804 non-null   Int64
#  26  id_pais_mae                        1134612 non-null  object
#  27  id_uf_mae                          1134611 non-null  object
#  28  id_municipio_mae                   1130066 non-null  object
#  29  id_pais_residencia                 782701 non-null   object
#  30  id_municipio_residencia            1171699 non-null  object
#  31  data_nascimento_mae                1018718 non-null  dbdate
#  32  idade_mae                          1171699 non-null  Int64
#  33  escolaridade_mae                   1127157 non-null  object
#  34  serie_escolar_mae                  600250 non-null   object
#  35  escolaridade_2010_mae              1104027 non-null  object
#  36  escolaridade_2010_agr_mae          1104027 non-null  object
#  37  estado_civil_mae                   1147201 non-null  object
#  38  ocupacao_mae                       917381 non-null   object
#  39  raca_cor_mae                       959901 non-null   object
#  40  gestacoes_ant                      1041263 non-null  Int64
#  41  quantidade_parto_normal            985210 non-null   Int64
#  42  quantidade_parto_cesareo           980762 non-null   Int64
#  43  data_ultima_menstruacao            753302 non-null   dbdate
#  44  tipo_apresentacao                  1117366 non-null  object
#  45  inducao_parto                      1098947 non-null  object
#  46  cesarea_antes_parto                992037 non-null   object
#  47  tipo_robson                        1171699 non-null  object
#  48  idade_pai                          168627 non-null   Int64
#  49  cartorio                           0 non-null        object
#  50  registro_cartorio                  0 non-null        object
#  51  data_registro_cartorio             0 non-null        dbdate
#  52  origem                             1171699 non-null  object
#  53  numero_lote                        1171692 non-null  Int64
#  54  versao_sistema                     1171692 non-null  object
#  55  data_cadastro                      1171698 non-null  dbdate
#  56  data_recebimento                   1170644 non-null  dbdate
#  57  data_recebimento_original          279864 non-null   dbdate
#  58  diferenca_data                     1171677 non-null  Int64
#  59  data_declaracao                    1117317 non-null  dbdate
#  60  funcao_responsavel                 1095839 non-null  object
#  61  documento_responsavel              1148451 non-null  object
#  62  formacao_profissional_responsavel  1143427 non-null  object
#  63  status_dn                          1171692 non-null  object
#  64  status_dn_nova                     1171699 non-null  object
#  65  paridade                           1171699 non-null  object
# dtypes: Int64(15), dbdate(8), dbtime(1), object(42)
# memory usage: 606.8+ MB
# None
#                ano         peso     apgar1     apgar5  semana_gestacao  \
# count    1171699.0    1171659.0  1154696.0  1154687.0        1123930.0
# mean   2018.082613  3209.958111   8.186777   9.049209        38.487868
# std       2.678033   571.682627   1.701112   1.441736         2.421943
# min         2014.0        100.0        0.0        0.0             19.0
# 25%         2016.0       2929.5        8.0        9.0             38.0
# 50%         2018.0       3250.0        8.0        9.0             39.0
# 75%         2020.0       3560.0        9.0        9.0             40.0
# max         2023.0       7000.0       99.0       99.0             45.0
#
#        pre_natal  quantidade_filhos_vivos  quantidade_filhos_mortos  \
# count  1124659.0                1044120.0                  983804.0
# mean    8.336492                 1.071859                  0.270337
# std     5.844783                 1.269897                   0.63177
# min          0.0                      0.0                       0.0
# 25%          6.0                      0.0                       0.0
# 50%          8.0                      1.0                       0.0
# 75%         10.0                      2.0                       0.0
# max         99.0                     99.0                      99.0
#
#        idade_mae  gestacoes_ant  quantidade_parto_normal  \
# count  1171699.0      1041263.0                 985210.0
# mean   26.565771       1.303736                 0.771576
# std     6.710615       1.479534                 1.309589
# min          8.0            0.0                      0.0
# 25%         21.0            0.0                      0.0
# 50%         26.0            1.0                      0.0
# 75%         31.0            2.0                      1.0
# max         99.0           99.0                     99.0
#
#        quantidade_parto_cesareo  idade_pai      numero_lote  diferenca_data
# count                  980762.0   168627.0        1171692.0       1171677.0
# mean                   0.371585  31.113493  20182098.809479       60.545421
# std                    0.696525   8.163317     26994.763961      108.619176
# min                         0.0        9.0       20140001.0             0.0
# 25%                         0.0       25.0       20160012.0            15.0
# 50%                         0.0       30.0       20180021.0            26.0
# 75%                         1.0       36.0       20200057.0            46.0
# max                        99.0       99.0       20230028.0           816.0
#
# Valores únicos em sigla_uf:
# ['CE']
#
# Valores únicos em sequencial_nascimento:
# ['263194' '1678088' '1649286' ... '186437' '186329' '186444']
#
# Valores únicos em id_municipio_nascimento:
# ['2305209' '2306405' '2303709' '2307650' '2307304' '2302602' '2306702'
#  '2311801' '2313302' '2308351' '2313005' '2311405' '2311306' '2304269'
#  '2302107' '2303600' '2308500' '2304707' '2612208' '2304301' '2306009'
#  '2301109' '2306900' '2408003' '2305605' '2308609' '2305902' '2304202'
#  '2304400' '2311264' '2312205' '2311355' '2311959' '2414100' '2400505'
#  '2409407' '2312403' '2208304' '2301307' '2302701' '2313203' '2309409'
#  '2312908' '2311009' '2309607' '2300754' '2308005' '2305803' '2313906'
#  '2307635' '2302404' '2311702' '2304004' '2313500' '2304509' '2313955'
#  '2302503' '2304103' '2114007' '2307106' '2308807' '2303808' '2309508'
#  '2303501' '2301703' '2300200' '2308302' '2302800' '2300705' '2313104'
#  '2307601' '2305407' '2313807' '2301406' '2312007' '2307502' '2307254'
#  '2307700' '2308104' '2313401' '2307809' '2300408' '2311900' '2310308'
#  '2303659' '2303402' '2313609' '2305308' '2305001' '2304236' '2310902'
#  '2314102' '2305233' '2309458' '2310258' '2310704' '2306306' '2312601'
#  '2310209' '2313351' '2304608' '2314003' '2304251' '2302305' '2301901'
#  '2516201' '2301851' '2304285' '2300903' '2312700' '2303006' '2308401'
#  '2311108' '2306603' '2306108' '2310852' '2312304' '2211001' '2303907'
#  '2307908' '2311207' '2302206' '2309003' '2311603' '2305506' '2309300'
#  '2310803' '2613503' '2310506' '2303956' '2601102' '2211308' '2306553'
#  '2308708' '2207702' '2307403' '2306801' '2303105' '2300309' '5208707'
#  '2301604' '3125101' '2313757' '2310100' '4205407' '5003702' '2302008'
#  '2208007' '2101202' '5300108' '2309102' '2300101' '2302909' '2300507'
#  '2303931' '2306504' '2300606' '2304459' '2301950' '2507507' '2301257'
#  '3301009' '2111300' '2303204' '2313559' '2304905' '2311504' '2305704'
#  '2305100' '2613909' '2307007' '2308203' '2303303' '3543907' '2305357'
#  '2308906' '5106224' '2503704' '2306256' '2300804' '2312106' '2309201'
#  '2310001' '2309706' '2309805' '2305266' '2108108' '2304350' '2312809'
#  '2310605' '2304657' '2304954' '2207900' '3518206' '3530805' '2910800'
#  '2302057' '2101400' '2310407' '1501709' '2408102' '5106752' '2304806'
#  '2305654' '2304277' '1302603' '2615607' '2313708' '2707107' '2306207'
#  '2301000' '2411007' '2104008' '2308377' '3550308' '2413607' '2305332'
#  '2307205' '2100436' '2301208' '2300150' '2604106' '2927408' '2310951'
#  '5002704' '3526902' '2502409' '2611101' '3106200' '2918407' '3205309'
#  '2301802' '2301505' '5107180' '1503804' '2611606' '2208403' '2313252'
#  '2605103' '5101704' '2933307' '2511400' '2401008' '4113700' '4321808'
#  '3549904' '3304557' '2309904' '2512101' '2403251' '2910727' '2925303'
#  '3552502' '2203909' '4305108' '2103000' '2704302' '3509502' '1501725'
#  '4314902' '2105302' '2412500' '3555406' '3524402' '2202604' '3138203'
#  '5006200' '2609154' '2603454' '2204303' '2102903' '3525904' '3551702'
#  '2920106' '2914802' '2208205' '2311231' '1505502' '2411205' '2101608'
#  '1502301' '2930105' '3101607' '2605707' '2614006' '2205508' '1502202'
#  '2103208' '3303302' '5103403' '3204906' '2929909' '4128005' '1501402'
#  '2917508' '3549409' '3303906' '3136702' '4106902' '5210109' '4218707'
#  '2112209' '2202208' '3543402' '3555000' '2207009' '1503705' '2612604'
#  '2900702' '2603009' '4314100' '3168705' '2516904' '2100055' '2510808'
#  '3202801' '4207502' '4104808' '2931350' '4303004' '2610004' '2603801'
#  '1600303' '2504306' '2924009' '3113305' '1303809' '2607901' '1508100'
#  '2411056' '1702109' '3526704' '4219507' '4202008' '2208106' '1503457'
#  '2104057' '2200202' '2610400' '2605301' '3112307' '2800308' '1507458'
#  '2601607' '2616407' '1505536' '2901601' '3550704' '2400901']
#
# Valores únicos em local_nascimento:
# ['3' '4' '1' '2' '9']
#
# Valores únicos em codigo_estabelecimento:
# [None '0133094' '2327945' '2327961' '2328003' '2328046' '2328100'
#  '2328119' '2328380' '2328399' '2328437' '2333716' '2333864' '2333880'
#  '2333899' '2356287' '2372150' '2372207' '2372479' '2372622' '2373009'
#  '2374064' '2410281' '2414848' '2414864' '2414872' '2415488' '0086673'
#  '2328429' '2372460' '2381125' '2407566' '2407574' '2409658' '2315386'
#  '2372487' '2372517' '2407868' '2415623' '2415658' '2426099' '2426579'
#  '2427125' '2427133' '2427176' '2427184' '2478080' '2478277' '2478293'
#  '2478307' '2478994' '2479028' '2479419' '2479427' '2479710' '2479818'
#  '2479893' '2479907' '2480646' '2480654' '2481073' '2481286' '2465469'
#  '2478285' '2482339' '2425599' '2478374' '2497654' '2499029' '2499037'
#  '2499363' '2514710' '2514729' '2516632' '2527391' '2527413' '2527685'
#  '2527693' '2527707' '2333813' '2409275' '2499312' '2499339' '2528282'
#  '2529068' '2552086' '2554518' '2554623' '2554798' '2560828' '2560836'
#  '2560852' '2560984' '2560992' '2561018' '2561026' '2561050' '2561298'
#  '2561328' '2561336' '2561344' '2561352' '2561409' '2561425' '2561433'
#  '2561441' '2561891' '2562138' '2562154' '2562200' '2562391' '2562499'
#  '2562146' '2562227' '2562545' '2562871' '2563460' '2563487' '2564211'
#  '2597314' '2611201' '2611295' '2611309' '2611465' '2611481' '2611643'
#  '2611686' '2425432' '2426749' '2478935' '2479478' '2564769' '2323397'
#  '2327953' '2333902' '2372495' '2372819' '2651351' '2664151' '2664666'
#  '2665190' '2675536' '2675560' '2675579' '2695839' '2705923' '2715163'
#  '2723212' '2723255' '2806215' '2528843' '2551926' '2554755' '2639254'
#  '2777789' '2806339' '3012034' '3021114' '3028429' '3053687' '3242587'
#  '3259749' '3286096' '3302490' '3394514' '3401146' '4009444' '4011325'
#  '5018110' '5077680' '6848710' '3345866' '2527677' '7043597' '7047428'
#  '7061021' '9247971' '9275134' '9297502' '2339137' '4010825' '5608910'
#  '2127881' '2562162' '2664283' '3157245' '2710935' '2724359' '2766876'
#  '6044433' '6922902' '7981457' '5247896' '2327996' '2328070' '2333848'
#  '2372509' '2372568' '2373475' '2399644' '2414996' '5108969' '2308231'
#  '2425343' '2480050' '2426218' '2426455' '2456958' '2526662' '2554771'
#  '2333740' '2348489' '2560976' '2561069' '2561468' '8015899' '2081032'
#  '2561042' '2563479' '2398680' '2613476' '2724308' '2563347' '2563355'
#  '2563363' '2328445' '2333856' '2664372' '2453347' '5590663' '6177417'
#  '6779522' '2323559' '9561501' '2772973' '6126057' '9699848' '2081814'
#  '2088193' '2562898' '2527065' '2529386' '6602533' '2610523' '2611058'
#  '3012611' '9568700' '9130454' '3499502' '4009622' '9170111' '9336508'
#  '2529394' '2664690' '2678403' '2639262' '2653931' '2679647' '2752654'
#  '3384993' '7396805' '7514948' '2554658' '9813071' '2012480' '2315300'
#  '2664364' '2721643' '0010472' '2372673' '2561395' '7870930' '2407434'
#  '2455625' '2079542' '2365154' '2380633' '2482304' '0010537' '2526670'
#  '2564238' '2373270' '2819899' '7274440' '7280416' '7021437' '2563681'
#  '2426730' '2517124' '7073224' '6999506' '2561034' '2529556' '2561271'
#  '4010779' '7434308' '2351994' '2563916' '5407591' '3649563' '7018800'
#  '3037495' '5183413' '2339080' '9262199' '0009725' '2081458' '2321963'
#  '2430711' '2371847' '2373513' '0027995' '2688611' '2713497' '2520524'
#  '2424266' '3188213' '6985483' '2552345' '5075416' '2499045' '2371707'
#  '2328038' '2424223' '2472791' '2312050' '9624864' '0000226' '2777746'
#  '2504545' '2564580' '0000418' '2711419' '2707527' '0010499' '2472457'
#  '2402564' '0010510' '2757710' '2562316' '6124925' '9515925' '6108547'
#  '3291146' '2550792' '2250837' '5259789' '6159397' '3037274' '0000434'
#  '2592568' '7103255' '2473380' '2507447' '2802090' '2079860' '2355906'
#  '2365146' '3356868' '2453665' '2089602' '9923837' '7371985' '2328410'
#  '2415631' '2022621' '2482274' '9031103' '2024632' '2726351' '2562685'
#  '2611236' '6893295' '2561131' '2561301' '2724332' '2679639' '2058391'
#  '2237601' '2328011' '0001120' '2430622' '2528711' '2526638' '2610949'
#  '7993218' '2328402' '2727064' '2452383' '7581467' '2381206' '3956369'
#  '2565374' '2702193' '9526293' '2085194' '2006472' '2517132' '2562693'
#  '2270269' '2364999' '6958753' '2112175' '0027944' '2371243' '2705842'
#  '2694301' '2463784' '2078767' '2084171' '7539797' '2611252' '2400324'
#  '4028511' '2525569' '7429398' '2490781' '2527669' '6426042' '2517140'
#  '2318628' '3759148' '4014111' '6807143' '2462583' '2081288' '2410478'
#  '7396732' '2415445' '2372967' '2616491' '2770512' '3001377' '2499053'
#  '2656957' '2171988' '2711893' '2349566' '3333333' '6968139' '2323540'
#  '7360347' '3006522' '3816567' '2452820' '2330962' '0012521' '3546527'
#  '6558143' '3056724' '6267815' '3008045' '3083721' '2365405' '6278035'
#  '2484072' '2639122' '3095541' '2664313' '2564823' '2733633' '2333031'
#  '2659107' '2223570' '2373831' '2649500' '2467372' '2478730' '2665182'
#  '2080044' '2748029' '3337146' '3972976' '3030121' '2111624' '2328062'
#  '0015318' '2426188' '2442531' '7556586' '2491710' '2717727' '7006810'
#  '2726653' '2479443' '2426617' '2562332' '2516640' '6303153' '3508188'
#  '2452782' '2424347' '9361359' '7547897' '0263672' '2528517' '2655411'
#  '2777797' '2078791' '3047091' '2080664' '2777762' '3513351' '2649497'
#  '2724634' '9046720' '2078015' '2615711' '2679663' '6400078' '6753469'
#  '2639173' '2424398' '2480298' '2487411' '0004170' '2639246' '3045625'
#  '5332427' '4011562' '3039269' '2246988' '2140217' '2082128' '6936040'
#  '2322730' '2463016' '7119232' '2694603' '7474261' '2528169' '2082888'
#  '2605414' '2479591' '7336578' '2521873' '0000106' '2364921' '2738368'
#  '2301008' '3295605' '6627595' '6476554' '2266474' '6251870' '2428393'
#  '2529149' '2424274' '2825309' '2346869' '2020890' '2592460' '2351668'
#  '2533480' '2764776' '4011627' '4004787' '3024644' '6556809' '2078376'
#  '3904784' '2319454' '2078066' '2381184' '2621614' '3205282' '6861873'
#  '2702886' '7547250' '2693755' '2755165' '2078074' '5253381' '9119701'
#  '2481103' '2333821' '2408236' '2411393' '0643335' '7389272' '7195907'
#  '2345889' '9787399' '2424355' '3136795' '3425398' '2082187' '2482444'
#  '2479281' '2364794' '2427427' '2616483' '2389746' '3528618' '2310821'
#  '7027397' '2323923' '2715384' '6043941' '2516683' '3455432' '2664410'
#  '2726319' '2563142' '2308649' '2431106' '2135124' '0002232' '2424371'
#  '2333430' '3427633' '4012070' '2269880' '2349574' '2712008' '2654032'
#  '2615762' '0010480' '2479222' '2799847' '6897886' '2077485' '2480026'
#  '2765934' '2077620' '2373203' '2409550' '6314740']
#
# Valores únicos em sexo:
# ['1' '2' '0' 'M' 'F' 'I']
#
# Valores únicos em raca_cor:
# ['4' '1' None '3' '2' '5' '9']
#
# Valores únicos em id_anomalia:
# ['2' None '1' '9']
#
# Valores únicos em codigo_anomalia:
# [None 'Q699' 'Q681' ... 'Q423Q541Q552Q668' 'Q435Q552Q670Q723Q764'
#  'Q380Q381']
#
# Valores únicos em semana_gestacao_estimada:
# ['9' '8' '2' '1' None]
#
# Valores únicos em gestacao_agr:
# ['5' '6' '4' '2' None '3' '1' '9']
#
# Valores únicos em tipo_gravidez:
# ['1' None '2' '3' '9']
#
# Valores únicos em tipo_parto:
# ['1' '2' None '9']
#
# Valores únicos em inicio_pre_natal:
# ['01' None '02' '04' '05' '03' '06' '99' '08' '07' '09' '10']
#
# Valores únicos em pre_natal_agr:
# ['4' '3' '2' '1' '9' None]
#
# Valores únicos em classificacao_pre_natal:
# ['5' '9' '2' '4' '3' '1']
#
# Valores únicos em id_pais_mae:
# ['823' '821' '822' '824' '831' '835' '826' '825' '833' '843' '813' None
#  '851' '811' '815' '829' '828' '832' '853' '852' '850' '812' '827' '841'
#  '842' '817' '814' '816' '253']
#
# Valores únicos em id_uf_mae:
# ['23' '21' '22' '24' '31' '35' '26' '25' '33' '43' '13' None '51' '11'
#  '15' '29' '28' '32' '53' '52' '50' '12' '27' '41' '42' '17' '14' '16']
#
# Valores únicos em id_municipio_mae:
# ['2305209' '2304400' '2102002' ... '2112274' '3154606' '2201606']
#
# Valores únicos em id_pais_residencia:
# ['1' None]
#
# Valores únicos em id_municipio_residencia:
# ['2305209' '2306405' '2310704' '2307650' '2307304' '2304707' '2307908'
#  '2302602' '2303907' '2302057' '2304509' '2313906' '2306702' '2311801'
#  '2307007' '2310001' '2313302' '2310308' '2300408' '2301505' '2308351'
#  '2313005' '2311405' '2311306' '2304269' '2302909' '2301406' '2302107'
#  '2309805' '2305100' '2301208' '2309102' '2306504' '2303600' '2308500'
#  '2310605' '2309607' '2300150' '2312403' '2304400' '2312601' '2313104'
#  '2303956' '2313500' '2311603' '2309706' '2307700' '2304301' '2306009'
#  '2304459' '2301109' '2305357' '2306207' '2302206' '2306900' '2310803'
#  '2305605' '2303659' '2305902' '2312304' '2303402' '2300804' '2311959'
#  '2304202' '2301604' '2313252' '2301307' '2302701' '2311207' '2300606'
#  '2309201' '2312106' '2303709' '2310209' '2311264' '2309409' '2310506'
#  '2311355' '2312809' '2307809' '2300903' '2304277' '2300705' '2311231'
#  '2313401' '2302305' '2305407' '2310902' '2302800' '2306108' '2308906'
#  '2306603' '2311504' '2308609' '2309300' '2308302' '2308401' '2313203'
#  '2301901' '2304905' '2312908' '2304350' '2308203' '2311009' '2300754'
#  '2312205' '2308005' '2313955' '2307635' '2302404' '2311702' '2304004'
#  '2310258' '2310852' '2305233' '2304954' '2306256' '2307205' '2302503'
#  '2308104' '2300101' '2302008' '2311108' '2301703' '2304103' '2301257'
#  '2305654' '2306553' '2306306' '2307403' '2305506' '2303303' '2308807'
#  '2304251' '2303105' '2300507' '2312007' '2305803' '2301000' '2303006'
#  '2303501' '2310100' '2301950' '2307601' '2307106' '2304608' '2304285'
#  '2309458' '2303808' '2314003' '2313708' '2309508' '2306801' '2303204'
#  '2300200' '2307254' '2310407' '2313807' '2313757' '2308708' '2313351'
#  '2305704' '2307502' '2312502' '2304236' '2311900' '2308377' '2313559'
#  '2314102' '2313609' '2305001' '2305308' '2304806' '2301851' '2301802'
#  '2312700' '2304657' '2300309' '2309003' '2309904' '2310951' '2305332'
#  '2303931' '2305266' '2504405' '2614303' '2605301' '2208205' '2612604'
#  '2609907' '2601102' '1302603' '2602001' '2613503' '2513356' '2509602'
#  '2208403' '2604304' '2408102' '2506608' '2606309' '2909901' '2505303'
#  '3201308' '2208106' '2615607' '2408003' '2610707' '2210409' '2409407'
#  '2502409' '2611101' '2900207' '2112902' '2609808' '3550308' '2507002'
#  '2100907' '2607307' '2111300' '2202703' '2615706' '2513307' '2507507'
#  '2503308' '2612208' '2400208' '2412500' '2514503' '2513505' '2927408'
#  '2509370' '2611606' '2202083' '2503704' '2613909' '2109908' '1505502'
#  '2516805' '2924009' '2211001' '2603454' '2505600' '2504009' '2709301'
#  '2412906' '2202026' '3548500' '2601201' '1600303' '5300108' '5208707'
#  '2401453' '1500800' '2608750' '2112605' '2401008' '2604007' '2614006'
#  '2207702' '2615201' '2414753' '2516904' '2603009' '2402303' '2208007'
#  '2903201' '2409308' '3509502' '1200203' '2609006' '2104701' '3138658'
#  '1502707' '2705903' '2600104' '2203909' '2210805' '3111200' '3304557'
#  '4103057' '2500700' '2209401' '2927101' '2905701' '2606002' '2607901'
#  '2204303' '2927903' '2209872' '2918407' '5213806' '2413359' '2604106'
#  '2502201' '3516309' '3548708' '2923001' '2102002' '1200104' '4309209'
#  '2612455' '1501402' '3546306' '2202604' '2616100' '2603405' '1400100'
#  '2502102' '2200277' '1504703' '2210003' '1505536' '2104206' '3303500'
#  '2509008' '1504422' '2207405' '2704302' '3159605' '2504306' '3551009'
#  '4216602' '2403707' '3302403' '2210706' '3134400' '3170800' '2516201'
#  '2202729' '4318705' '2206506' '3518701' '2602308' '1721000' '2803203'
#  '2402006' '2409506' '5205497' '2210607' '2906808' '2110609' '2201804'
#  '3302502' '4119905']
#
# Valores únicos em escolaridade_mae:
# ['4' '3' '5' None '1' '2' '9' '0']
#
# Valores únicos em serie_escolar_mae:
# ['2' '3' '6' None '8' '1' '4' '5' '7']
#
# Valores únicos em escolaridade_2010_mae:
# ['3' '2' '5' '4' '1' None '0' '9']
#
# Valores únicos em escolaridade_2010_agr_mae:
# ['05' '06' '03' '08' '07' '04' '02' '12' None '11' '00' '01' '10' '09']
#
# Valores únicos em estado_civil_mae:
# ['5' '1' None '2' '4' '9' '3']
#
# Valores únicos em ocupacao_mae:
# ['622020' None '999992' ... '768310' '223119' '203220']
#
# Valores únicos em raca_cor_mae:
# ['4' '1' None '3' '2' '5' '9']
#
# Valores únicos em tipo_apresentacao:
# ['1' '2' None '9' '3']
#
# Valores únicos em inducao_parto:
# ['2' '9' None '1']
#
# Valores únicos em cesarea_antes_parto:
# ['3' '2' '9' None '1']
#
# Valores únicos em tipo_robson:
# ['01' '02' '03' '04' '05' '06' '07' '08' '09' '10' '11']
#
# Valores únicos em cartorio:
# [None]
#
# Valores únicos em registro_cartorio:
# [None]
#
# Valores únicos em origem:
# ['1' '2' '3']
#
# Valores únicos em versao_sistema:
# ['3.2.00' '3.2.02' '3.2.01' '3.2.50' None '2.2.03' '2.2.00' '2.2.08']
#
# Valores únicos em funcao_responsavel:
# ['2' None '5' '1' '3' '4' '0']
#
# Valores únicos em documento_responsavel:
# ['3' '0' '4' '5' '1' '2' None]
#
# Valores únicos em formacao_profissional_responsavel:
# ['3' '9' '1' '2' '4' None]
#
# Valores únicos em status_dn:
# ['0' None '1']
#
# Valores únicos em status_dn_nova:
# ['1' '0']
#
# Valores únicos em paridade:
# ['0' '1']
# ano                                      0
# sigla_uf                                 0
# sequencial_nascimento                    0
# id_municipio_nascimento                  0
# local_nascimento                         0
#                                      ...
# documento_responsavel                23248
# formacao_profissional_responsavel    28272
# status_dn                                7
# status_dn_nova                           0
# paridade                                 0
# Length: 66, dtype: int64
